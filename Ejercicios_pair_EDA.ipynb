# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
#1.1. 
# Muestra las primeras 5 filas del conjunto de datos.

# %% [markdown]
# Ejercicios de exploración del conjunto de datos
# Muestra las primeras 5 filas del conjunto de datos.
#
# 1. Muestra las últimas 5 filas del conjunto de datos.

# %%
df = pd.read_csv("world-data-2023_part1.csv", index_col=0)

# %%
df.head(5)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# ...

# %%
df.tail()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 190  Venezuela               32           VE                24.50%
# 191    Vietnam              314           VN                39.30%
# 192      Yemen               56           YE                44.60%
# 193     Zambia               25           ZM                32.10%
# 194   Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 190            Caracas       164,175  2,740.27        254.90%           VED
# ...

# %% [markdown]
# 2. Muestra una muestra aleatoria de 5 filas del conjunto de datos.

# %%
df.sample(5)
# Out:
#         Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 29   Cape Verde              138           CV                19.60%
# 191     Vietnam              314           VN                39.30%
# 167    Suriname                4           SR                 0.60%
# 9       Austria              109           AT                32.40%
# 62   The Gambia              239           GM                59.80%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 29           4,033             1,000       19.49         238.0
# 191        331,210           522,000       16.75          84.0
# 167        163,820             2,000       18.54         597.0
# 9           83,871            21,000        9.70          43.0
# 62          11,300             1,000       38.54         220.0
#
#     Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 29               Praia           543   110.5          1.10%           CVE
# ...

# %% [markdown]
# 3. Muestra el nombre de todas las columnas en el conjunto de datos.

# %%
df.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price'],
#       dtype='object')

# %% [markdown]
# 4. Muestra los valores únicos en la columna "Abbreviation".

# %%
df["Abbreviation"].unique
# Out:
# <bound method Series.unique of 0      AF
# 1      AL
# 2      DZ
# 3      AD
# 4      AO
#        ..
# 190    VE
# 191    VN
# 192    YE
# 193    ZM
# 194    ZW
# Name: Abbreviation, Length: 195, dtype: object>

# %% [markdown]
# 5. Cuenta cuántas veces aparece cada valor único en la columna "Abbreviation".

# %%
df["Abbreviation"].nunique()
# Out:
# 188

# %% [markdown]
# 6. Verifica si hay valores nulos en el conjunto de datos.

# %%
df.isnull() #.isna()
# Out:
#      Country  Density\n(P/Km2)  Abbreviation  Agricultural Land( %)  \
# 0      False             False         False                  False
# 1      False             False         False                  False
# 2      False             False         False                  False
# 3      False             False         False                  False
# 4      False             False         False                  False
# ..       ...               ...           ...                    ...
# 190    False             False         False                  False
# 191    False             False         False                  False
# 192    False             False         False                  False
# 193    False             False         False                  False
# 194    False             False         False                  False
#
#      Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 0             False              False       False         False
# ...

# %% [markdown]
# 7. Verifica si hay valores no nulos en el conjunto de datos.

# %%
df.notnull()
# Out:
#      Country  Density\n(P/Km2)  Abbreviation  Agricultural Land( %)  \
# 0       True              True          True                   True
# 1       True              True          True                   True
# 2       True              True          True                   True
# 3       True              True          True                   True
# 4       True              True          True                   True
# ..       ...               ...           ...                    ...
# 190     True              True          True                   True
# 191     True              True          True                   True
# 192     True              True          True                   True
# 193     True              True          True                   True
# 194     True              True          True                   True
#
#      Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 0              True               True        True          True
# ...

# %% [markdown]
# 8. Muestra información general sobre el conjunto de datos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195 entries, 0 to 194
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                195 non-null    object
#  1   Density
# (P/Km2)        195 non-null    object
#  2   Abbreviation           188 non-null    object
#  3   Agricultural Land( %)  188 non-null    object
#  4   Land Area(Km2)         194 non-null    object
#  5   Armed Forces size      171 non-null    object
#  6   Birth Rate             189 non-null    float64
#  7   Calling Code           194 non-null    float64
#  8   Capital/Major City     192 non-null    object
#  9   Co2-Emissions          188 non-null    object
#  10  CPI                    178 non-null    object
#  11  CPI Change (%)         179 non-null    object
#  12  Currency-Code          180 non-null    object
#  13  Fertility Rate         188 non-null    float64
# ...

# %% [markdown]
# 9. Elimina una columna específica (por ejemplo, "Armed Forces size").

# %%
df.drop(columns = ["Armed Forces size"], inplace=True)

# %%
df.head(2)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
#
#   Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 0        652,230       32.49          93.0              Kabul         8,672
# 1         28,748       11.78         355.0             Tirana         4,536
#
#       CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 0   149.9          2.30%           AFN            4.47             2.10%
# 1  119.05          1.40%           ALL            1.62            28.10%
#
#   Gasoline Price
# 0         $0.70
# 1         $1.36

# %% [markdown]
# 10. Selecciona las columnas numéricas del conjunto de datos y muestra sus estadísticas descriptivas básicas (para esto tendréis que usar el método '.describe(), su documentación la tenéis aquí).

# %%
df.describe().T
# Out:
#                 count        mean         std   min     25%      50%  \
# Birth Rate      189.0   20.214974    9.945774  5.90  11.300   17.950
# Calling Code    194.0  360.546392  323.236419  1.00  82.500  255.500
# Fertility Rate  188.0    2.698138    1.282267  0.98   1.705    2.245
#
#                      75%      max
# Birth Rate       28.7500    46.08
# Calling Code    506.7500  1876.00
# Fertility Rate    3.5975     6.91

# %%
df.describe().count
# Out:
# <bound method DataFrame.count of        Birth Rate  Calling Code  Fertility Rate
# count  189.000000    194.000000      188.000000
# mean    20.214974    360.546392        2.698138
# std      9.945774    323.236419        1.282267
# min      5.900000      1.000000        0.980000
# 25%     11.300000     82.500000        1.705000
# 50%     17.950000    255.500000        2.245000
# 75%     28.750000    506.750000        3.597500
# max     46.080000   1876.000000        6.910000>

# %%
df.describe().min
# Out:
# <bound method DataFrame.min of        Birth Rate  Calling Code  Fertility Rate
# count  189.000000    194.000000      188.000000
# mean    20.214974    360.546392        2.698138
# std      9.945774    323.236419        1.282267
# min      5.900000      1.000000        0.980000
# 25%     11.300000     82.500000        1.705000
# 50%     17.950000    255.500000        2.245000
# 75%     28.750000    506.750000        3.597500
# max     46.080000   1876.000000        6.910000>

# %%
df.describe().max
# Out:
# <bound method DataFrame.max of        Birth Rate  Calling Code  Fertility Rate
# count  189.000000    194.000000      188.000000
# mean    20.214974    360.546392        2.698138
# std      9.945774    323.236419        1.282267
# min      5.900000      1.000000        0.980000
# 25%     11.300000     82.500000        1.705000
# 50%     17.950000    255.500000        2.245000
# 75%     28.750000    506.750000        3.597500
# max     46.080000   1876.000000        6.910000>
